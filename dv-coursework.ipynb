# %% [markdown]
# # 📌 Summary of Your F20DV Group Project Coursework
#
# Your **Data Visualization and Analytics** coursework involves creating an **interactive data visualization application** using **D3.js**, working in groups of **4**.
#
# ## 🔹 1. Project Overview
# - **Choose and analyze** a dataset.
# - Build an **interactive data visualization application** using **D3.js**.
# - Ensure the application allows users to **explore, filter, and gain insights**.
# - Submit your project through **GitLab** and **Canvas**.
#
# ### ⏳ Weightage:
# ✅ **60%** of your final course grade:
# - **Group project (50%)**: Design, development, demonstration.
# - **Individual report (10%)**: Personal contributions and reflection.
#
# ---
#
# ## 🔹 2. Key Project Stages & Deadlines
#
# | **Stage**   | **Task**                                         | **Deadline**           |
# |------------|------------------------------------------------|-----------------------|
# | **Stage 0** | Form groups & register on Canvas             | Week 4 (**7th Feb 2025**) |
# | **Stage 1** | Select dataset, register it, and justify choices | Week 4 |
# | **Stage 2** | Design the application, create mockups, and present | Week 8 (**7th Mar 2025**) |
# | **Stage 3** | Develop interactive **D3.js** visualizations  | Week 8 - 11 |
# | **Stage 4** | **Final demonstration** (7-min presentation) | Week 12 (**6th Apr 2025**) |
# | **Final Submission** | Submit project code & individual report | Week 11 (**28th Mar 2025**) |
# | **Peer Review** | Evaluate group members' contributions | Week 12 |
#
# ---
#
# ## 🔹 3. Project Requirements
#
# ### 📂 Dataset Requirements
# ✅ Must have:
# - At least **12 attributes** (**categorical + numerical**).
# - At least **50 records** per dataset (or **200+** if using one dataset).
# - **Complex structure** (hierarchical or geographical).
# - **Publicly available & legally usable**.
#
# ### 💻 Application Requirements
#
# #### ✅ **Minimum Passing Criteria (40%)**
# - Must be a **single-page web application**.
# - Implemented using **D3.js (v7+), HTML, CSS, JavaScript** (No extra libraries unless approved).
# - Includes **interactive elements** to explore data.
# - Uses **GitLab** for collaboration.
# - Must show **data insights through visualization**.
#
# #### ✅ **Full Marks Requirements**
# - At least **4 different interactive chart types**.
# - One **unique/creative visualization** not covered in lectures.
# - Two **linked visualizations** with bidirectional interactions.
# - **Smooth animations & consistent UI styling**.
# - One visualization showing a **"positive" story** & another showing a **"negative" story**.
# - Well-documented **README** & **code comments**.
#
# ---
#
# ## 🔹 4. Project Deliverables
#
# ### 📊 **Design Presentation (Week 8) - 10%**
# ✅ Covers:
# - **Dataset selection and analysis**.
# - **Mockups of visualizations & interactions**.
# - **Justification of design choices**.
#
# ### ⚙️ **Final Project Submission (Week 11) - 30%**
# ✅ Must include:
# - **D3.js-based interactive visualizations**.
# - **Dynamic data loading & transformations**.
# - **Meaningful user interactions** (filtering, linking, storytelling).
# - Well-structured & documented **code** (**README + comments**).
#
# ### 🎤 **Final Demonstration (Week 12) - 10%**
# ✅ 7-minute presentation covering:
# - Implemented **visualizations and interactions**.
# - How **users can explore and analyze** the dataset.
# - **Changes made based on feedback**.
#
# ### 📄 **Individual Report (Week 11) - 10%**
# ✅ Must reflect on:
# - **Personal contributions & challenges**.
# - **Technical and teamwork experiences**.
# - **Lessons learned & possible improvements**.
#
# ### 📝 **Peer Review (Week 12) - Modifier (+5/-5 marks)**
# - Evaluates each group member’s **contributions**.
# - **Significant lack of contribution** → **Deduction of up to 5 marks**.
#
# ---
#
# ## 🔹 5. Marking Rubrics
#
# | **Component**         | **Weightage** | **Key Focus** |
# |----------------------|-------------|-------------|
# | **Design Presentation** | **10%** | Dataset choice, analysis, mockups, storytelling |
# | **Final Project Code** | **30%** | Data processing, visualization quality, interactivity, design |
# | **Demonstration** | **10%** | Clarity, storytelling, interaction explanation |
# | **Individual Report** | **10%** | Reflection on contributions, challenges, and learnings |
# | **Peer Review** | **Modifier (+5/-5)** | Group contribution balance |
#
# ---
#
# ## 🔹 6. Next Steps for You
#
# ✅ **Step 1:** Group Formation (**Ensure you're in a team of 4**).
# ✅ **Step 2:** Dataset Selection (**Find a complex dataset that fits the criteria**).
# ✅ **Step 3:** Design & Mockups (**Plan how your visualization will look**).
# ✅ **Step 4:** Development (**Start implementing charts in D3.js**).
# ✅ **Step 5:** Testing & Iteration (**Ensure usability, interactions, and performance**).
# ✅ **Step 6:** Documentation & Final Submission (**README, comments, report**).
#
# ---
#
# # 📌 Evaluating Your UAE Rental Properties Dataset for the Project
#
# Your dataset appears **very strong** for your **D3.js interactive data visualization project**! ✅
#
# ## 1️⃣ Dataset Strengths (**Why It’s a Good Choice**)
# ✅ **Rich Attributes**: The dataset contains **numerical, categorical, and geographical data**, allowing multiple types of visualizations.
# ✅ **Well-Structured**: Clearly defined fields like **Rent, Beds, Baths, Area_in_sqft, City, Latitude/Longitude**.
# ✅ **Multiple Insights Possible**:
# - **Rental Market Trends** (price distribution, high vs low rent areas).
# - **Geographical Mapping** (using **Latitude & Longitude** for heatmaps).
# - **Comparison of Property Types** (e.g., **Apartments vs Villas**).
# ✅ **Time-Based Analysis**: The **Posted_date** and **Age_of_listing_in_days** allow **trend analysis over time**.
#
# ---
#
# ## 2️⃣ Potential Visualizations Using D3.js
#
# | **Visualization Type** | **What It Shows** | **D3 Features Used** |
# |---------------------|----------------|------------------|
# | **Bar Chart** | Average rent per city | `d3.scaleBand()`, `d3.axisBottom()` |
# | **Scatter Plot** | Rent vs. Area (sqft) | `d3.scaleLinear()`, `d3.axisLeft()` |
# | **Heatmap** | Rent distribution across UAE | `d3.geoPath()`, `d3.scaleSequential()` |
# | **Treemap** | Number of properties per type | `d3.treemap()` |
# | **Line Chart** | Rent trends over time | `d3.line()`, `d3.axisBottom()` |
# | **Bubble Chart** | Rent per sqft vs Area | `d3.forceSimulation()` |
#
# ---
#
# ## 3️⃣ Next Steps
# 🚀 **Confirm Dataset Quality**: I'll check for **missing values, inconsistencies, and potential issues** in the dataset.
# 🚀 **Preprocess Data (if needed)**: Remove **duplicates, fix data types, or add computed columns**.
# 🚀 **Recommend Best Visualizations**: Based on what the data allows.  ****

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/real-estate-goldmine-dubai-uae-rental-market/dubai_properties.csv

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/kaggle/input/real-estate-goldmine-dubai-uae-rental-market/dubai_properties.csv")  # Change to your file path

# Display first few rows
print(df.head())
# Out:
#                                              Address    Rent  Beds  Baths  \
# 0  The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2            Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3  Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                    West Yas, Yas Island, Abu Dhabi  350000     5      7
#
#         Type  Area_in_sqft  Rent_per_sqft Rent_category Frequency  \
# 0  Apartment          1785      69.467787        Medium    Yearly
# 1  Apartment          1422      98.452883        Medium    Yearly
# 2  Apartment          1314      75.342466        Medium    Yearly
# 3  Penthouse          3843      57.246942          High    Yearly
# 4      Villa          6860      51.020408          High    Yearly
#
#     Furnishing   Purpose Posted_date  Age_of_listing_in_days        Location  \
# ...

# %%
# Check data types and missing values
print(df.info())

# Check summary statistics
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73742 entries, 0 to 73741
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Address                 73742 non-null  object
#  1   Rent                    73742 non-null  int64
#  2   Beds                    73742 non-null  int64
#  3   Baths                   73742 non-null  int64
#  4   Type                    73742 non-null  object
#  5   Area_in_sqft            73742 non-null  int64
#  6   Rent_per_sqft           73742 non-null  float64
#  7   Rent_category           73742 non-null  object
#  8   Frequency               73742 non-null  object
#  9   Furnishing              73742 non-null  object
#  10  Purpose                 73742 non-null  object
#  11  Posted_date             73742 non-null  object
#  12  Age_of_listing_in_days  73742 non-null  int64
#  13  Location                73742 non-null  object
# ...

# %%
print(df.isnull().sum())
# Out:
# Address                     0
# Rent                        0
# Beds                        0
# Baths                       0
# Type                        0
# Area_in_sqft                0
# Rent_per_sqft               0
# Rent_category               0
# Frequency                   0
# Furnishing                  0
# Purpose                     0
# Posted_date                 0
# Age_of_listing_in_days      0
# Location                    0
# City                        0
# Latitude                  719
# Longitude                 719
# dtype: int64

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/kaggle/input/real-estate-goldmine-dubai-uae-rental-market/dubai_properties.csv")  # Change path as needed

# Drop rows where Latitude or Longitude are missing
df_cleaned = df.dropna(subset=["Latitude", "Longitude"])

# Save the cleaned dataset
df_cleaned.to_csv("/kaggle/working/cleaned_dataset.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
# Check data types and missing values
print(df_cleaned.info())

# Check summary statistics
print(df_cleaned.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73023 entries, 0 to 73738
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Address                 73023 non-null  object
#  1   Rent                    73023 non-null  int64
#  2   Beds                    73023 non-null  int64
#  3   Baths                   73023 non-null  int64
#  4   Type                    73023 non-null  object
#  5   Area_in_sqft            73023 non-null  int64
#  6   Rent_per_sqft           73023 non-null  float64
#  7   Rent_category           73023 non-null  object
#  8   Frequency               73023 non-null  object
#  9   Furnishing              73023 non-null  object
#  10  Purpose                 73023 non-null  object
#  11  Posted_date             73023 non-null  object
#  12  Age_of_listing_in_days  73023 non-null  int64
#  13  Location                73023 non-null  object
# ...

# %%
print(df_cleaned.isnull().sum())
# Out:
# Address                   0
# Rent                      0
# Beds                      0
# Baths                     0
# Type                      0
# Area_in_sqft              0
# Rent_per_sqft             0
# Rent_category             0
# Frequency                 0
# Furnishing                0
# Purpose                   0
# Posted_date               0
# Age_of_listing_in_days    0
# Location                  0
# City                      0
# Latitude                  0
# Longitude                 0
# dtype: int64

# %%
print(df_cleaned.nunique())
# Out:
# Address                    4389
# Rent                       2094
# Beds                         13
# Baths                        11
# Type                          9
# Area_in_sqft               4943
# Rent_per_sqft             31159
# Rent_category                 3
# Frequency                     1
# Furnishing                    2
# Purpose                       1
# Posted_date                 538
# Age_of_listing_in_days      538
# Location                    359
# City                          8
# Latitude                    412
# Longitude                   412
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.histplot(df_cleaned["Rent"], bins=20, kde=True)
plt.title("Distribution of Rent Prices")
plt.xlabel("Rent (AED)")
plt.ylabel("Count")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset (Update file path based on Kaggle's environment)
file_path = "/kaggle/working/cleaned_dataset.csv"  # Update this with your file path
df = pd.read_csv(file_path)

# Drop rows where Latitude or Longitude are missing
df_cleaned = df.dropna(subset=["Latitude", "Longitude"])

# Set seaborn style
sns.set_style("whitegrid")

# Create subplots
fig, axes = plt.subplots(3, 2, figsize=(15, 15))

# 1. Histogram of Rent Prices
sns.histplot(df_cleaned["Rent"], bins=30, kde=True, ax=axes[0, 0])
axes[0, 0].set_title("Distribution of Rent Prices")
axes[0, 0].set_xlabel("Rent (AED)")
axes[0, 0].set_ylabel("Count")

# 2. Rent Category Count
sns.countplot(x=df_cleaned["Rent_category"], palette="viridis", ax=axes[0, 1])
axes[0, 1].set_title("Number of Listings by Rent Category")
axes[0, 1].set_xlabel("Rent Category")
axes[0, 1].set_ylabel("Count")

# 3. Beds and Baths Distribution
sns.countplot(x=df_cleaned["Beds"], ax=axes[1, 0], palette="coolwarm")
axes[1, 0].set_title("Distribution of Bedroom Counts")

sns.countplot(x=df_cleaned["Baths"], ax=axes[1, 1], palette="coolwarm")
axes[1, 1].set_title("Distribution of Bathroom Counts")

# 4. Rent vs Area Scatter Plot
sns.scatterplot(x=df_cleaned["Area_in_sqft"], y=df_cleaned["Rent"], ax=axes[2, 0])
axes[2, 0].set_title("Rent vs Area in Sqft")
axes[2, 0].set_xlabel("Area (Sqft)")
axes[2, 0].set_ylabel("Rent (AED)")

# 5. Rent Distribution by Furnishing Type
sns.boxplot(x="Furnishing", y="Rent", data=df_cleaned, ax=axes[2, 1])
axes[2, 1].set_title("Rent Distribution by Furnishing Type")
axes[2, 1].set_xlabel("Furnishing Type")
axes[2, 1].set_ylabel("Rent (AED)")

# Adjust layout
plt.tight_layout()
plt.show()

# Display correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_cleaned.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Features")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c4c1e01d8e74> in <cell line: 55>()
#      53 # Display correlation heatmap
#      54 plt.figure(figsize=(10, 6))
# ---> 55 sns.heatmap(df_cleaned.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
#      56 plt.title("Correlation Heatmap of Features")
#      57 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
# ...

# %%
# Select only numeric columns for correlation matrix
numeric_cols = df_cleaned.select_dtypes(include=['number'])

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_cols.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()
